# %% [markdown]
# # Welcome to the Anime Rating Comparator!
#
# This project is designed to compare various anime ratings to other title data points.

# %%
# Library import statements
import sqlite3
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Uses pandas to read dataset and stores via python as a variable
anime_data = pd.read_csv("anime.csv")

# %% [markdown]
# Here is the main data set used for this project. This data comes from the myanimelist.net API, a collection of data pulled from 12294 anime titles and 73516 users of one of the leading anime-related database sites on the internet. Though slightly outdated, the data from this API still overall accurately reflects the current state of the various title ratings, especially when user votes are into the thousands.
#
# You can view the original data set here: https://www.kaggle.com/CooperUnion/anime-recommendations-database
#
# For purposes of having the most rounded possible view of the data, titles with less than 1000 user votes are still included in the queries, graphs, and analyses, as there are enough of these titles in the main data set to not be considered outliers in individual categorical analysis. However, anything tagged as adult-oriented has been excluded and removed from the original data set, as these points do act as outliers, and are not necessary for a proper analysis of the data. This exclusion reduces the total number of data points in the population to 11153, which is still perfectly viable for these analyses.

# %%
# Main data table
anime_data
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6         11061                             Hunter x Hunter (2011)
# 7           820                               Ginga Eiyuu Densetsu
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9         15417                           Gintama&#039;: Enchousen
# 10         4181                               Clannad: After Story
# 11        28851                                     Koe no Katachi
# 12          918                                            Gintama
# 13         2904                 Code Geass: Hangyaku no Lelouch R2
# 14        28891                            Haikyuu!! Second Season
# 15          199                      Sen to Chihiro no Kamikakushi
# 16        23273                            Shigatsu wa Kimi no Uso
# 17        24701                      Mushishi Zoku Shou 2nd Season
# 18        12355                       Ookami Kodomo no Ame to Yuki
# 19         1575                    Code Geass: Hangyaku no Lelouch
# 20          263                                     Hajime no Ippo
# 21           44  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 22            1                                       Cowboy Bebop
# 23        30276                                      One Punch Man
# 24          164                                      Mononoke Hime
# 25         7311                      Suzumiya Haruhi no Shoushitsu
# 26        17074                   Monogatari Series: Second Season
# 27        21939                                 Mushishi Zoku Shou
# 28          457                                           Mushishi
# 29         2001                         Tengen Toppa Gurren Lagann
# ...         ...                                                ...
# 11123      5719                                        Sex Pistols
# 11124       747                                  Haru wo Daite Ita
# 11125      5784                                Ai no Kusabi (2012)
# 11126       734                         Kizuna: Koi no kara Sawagi
# 11127      2417                          Saigo no Door wo Shimero!
# 11128      9761                                      Finder Series
# 11129      1041                                       Zetsuai 1989
# 11130      1042                         Bronze: Zetsuai Since 1989
# 11131      2148                                       Okane ga Nai
# 11132       746                           Papa to Kiss in the Dark
# 11133       733                                             Kizuna
# 11134     30262                              Okane ga Nai Specials
# 11135      8339                                      Kachou no Koi
# 11136      8577                             Aki-Sora: Yume no Naka
# 11137     10845                          Manyuu Hikenchou Specials
# 11138     10920                  Seikon no Qwaser II Picture Drama
# 11139      9232                             Yebisu Celebrities 1st
# 11140      1496                     Fushigi no Kuni no Miyuki-chan
# 11141     12239                     Manyuu Hikenchou Picture Drama
# 11142      2218                     Fujimi 2-choume Koukyougakudan
# 11143      2169                                                Ice
# 11144      4149                  Body Jack: Tanoshii Yutai Ridatsu
# 11145     31283                            Bikini Warriors Special
# 11146      9600                                     G-Taste (2010)
# 11147      2592                                             Kimera
# 11148       730                           Houkago no Shokuinshitsu
# 11149      6546                       Pico: My Little Summer Story
# 11150     30663                                     Docchi mo Maid
# 11151     34382                                             Citrus
# 11152     33654                                 Hitorijime My Hero
#
#                                                    genre     type episodes  \
# 0                   Drama, Romance, School, Supernatural    Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...       TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...       TV       51
# 3                                       Sci-Fi, Thriller       TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...       TV       51
# 5                 Comedy, Drama, School, Shounen, Sports       TV       10
# 6                Action, Adventure, Shounen, Super Power       TV      148
# 7                         Drama, Military, Sci-Fi, Space      OVA      110
# 8      Action, Comedy, Historical, Parody, Samurai, S...    Movie        1
# 9      Action, Comedy, Historical, Parody, Samurai, S...       TV       13
# 10     Drama, Fantasy, Romance, Slice of Life, Supern...       TV       24
# 11                                Drama, School, Shounen    Movie        1
# 12     Action, Comedy, Historical, Parody, Samurai, S...       TV      201
# 13     Action, Drama, Mecha, Military, Sci-Fi, Super ...       TV       25
# 14                Comedy, Drama, School, Shounen, Sports       TV       25
# 15                        Adventure, Drama, Supernatural    Movie        1
# 16                Drama, Music, Romance, School, Shounen       TV       22
# 17     Adventure, Fantasy, Historical, Mystery, Seine...       TV       10
# 18                                Fantasy, Slice of Life    Movie        1
# 19     Action, Mecha, Military, School, Sci-Fi, Super...       TV       25
# 20                        Comedy, Drama, Shounen, Sports       TV       75
# 21     Action, Drama, Historical, Martial Arts, Roman...      OVA        4
# 22       Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 23     Action, Comedy, Parody, Sci-Fi, Seinen, Super ...       TV       12
# 24                            Action, Adventure, Fantasy    Movie        1
# 25     Comedy, Mystery, Romance, School, Sci-Fi, Supe...    Movie        1
# 26       Comedy, Mystery, Romance, Supernatural, Vampire       TV       26
# 27     Adventure, Fantasy, Historical, Mystery, Seine...       TV       10
# 28     Adventure, Fantasy, Historical, Mystery, Seine...       TV       26
# 29              Action, Adventure, Comedy, Mecha, Sci-Fi       TV       27
# ...                                                  ...      ...      ...
# 11123                  Comedy, Drama, Supernatural, Yaoi      OVA        2
# 11124                               Drama, Romance, Yaoi      OVA        2
# 11125                       Drama, Romance, Sci-Fi, Yaoi      OVA        4
# 11126                               Drama, Romance, Yaoi      OVA        1
# 11127                       Comedy, Drama, Romance, Yaoi      OVA        1
# 11128                                Action, Drama, Yaoi      OVA        2
# 11129                Drama, Music, Romance, Sports, Yaoi      OVA        1
# 11130                Drama, Music, Romance, Sports, Yaoi      OVA        1
# 11131                               Drama, Romance, Yaoi      OVA        4
# 11132                       Comedy, Drama, Romance, Yaoi      OVA        2
# 11133                               Drama, Romance, Yaoi      OVA        2
# 11134                               Drama, Romance, Yaoi  Special        4
# 11135                              Comedy, Romance, Yaoi      OVA        1
# 11136                       Ecchi, Romance, Seinen, Yuri      OVA        2
# 11137                        Action, Ecchi, Seinen, Yuri  Special        4
# 11138                                        Ecchi, Yuri  Special        4
# 11139                                               Yaoi      OVA        1
# 11140            Comedy, Ecchi, Fantasy, Shoujo Ai, Yuri      OVA        2
# 11141                                Ecchi, Seinen, Yuri  Special        4
# 11142  Drama, Music, Psychological, Romance, Slice of...      OVA        1
# 11143          Action, Military, Sci-Fi, Shoujo Ai, Yuri      OVA        3
# 11144                                Comedy, Ecchi, Yuri      OVA        1
# 11145               Comedy, Ecchi, Fantasy, Parody, Yuri  Special        1
# 11146                                        Ecchi, Yuri      OVA        1
# 11147  Action, Horror, Sci-Fi, Supernatural, Vampire,...      OVA        1
# 11148                               Drama, Romance, Yaoi      OVA        2
# 11149                                               Yaoi      OVA        1
# 11150                        Action, Comedy, Ecchi, Yuri      ONA        1
# 11151                       Drama, Romance, School, Yuri      NaN  Unknown
# 11152                                               Yaoi      NaN  Unknown
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# 5        9.15    93351
# 6        9.13   425855
# 7        9.11    80679
# 8        9.10    72534
# 9        9.11    81109
# 10       9.06   456749
# 11       9.05   102733
# 12       9.04   336376
# 13       8.98   572888
# 14       8.93   179342
# 15       8.93   466254
# 16       8.92   416397
# 17       8.88    75894
# 18       8.84   226193
# 19       8.83   715151
# 20       8.83   157670
# 21       8.83   129307
# 22       8.82   486824
# 23       8.82   552458
# 24       8.81   339556
# 25       8.81   240297
# 26       8.80   205959
# 27       8.80   101351
# 28       8.78   300030
# 29       8.78   562962
# ...       ...      ...
# 11123    7.00    15885
# 11124    6.99    15269
# 11125    6.97    17943
# 11126    6.94     4127
# 11127    6.76     9076
# 11128    6.70     8792
# 11129    6.69     7117
# 11130    6.67     6824
# 11131    6.58    27367
# 11132    6.47    28620
# 11133    6.46     6547
# 11134    6.46     1285
# 11135    6.43     6890
# 11136    6.41    37519
# 11137    6.23     6179
# 11138    6.19     6874
# 11139    6.08     5082
# 11140    6.00     7240
# 11141    5.85     4060
# 11142    5.72     4981
# 11143    5.68     5247
# 11144    5.51     1073
# 11145    5.50     5191
# 11146    5.49     1445
# 11147    5.29     3374
# 11148    5.23     4550
# 11149    5.21     5551
# 11150    5.15      223
# 11151     NaN     2459
# 11152     NaN     1574
#
# [11153 rows x 7 columns]

# %%
# Allows the data to be accessed via SQL queries
anime_data.to_sql("anime_data_sql", sqlite3.connect("anime.db"), if_exists = "replace")

# %% [markdown]
# **Correlations between Type and User Votes**
#
# We will begin with User Votes. Is there a correlation between higher ratings and the amount of users that vote on something?
#
# Does this correlation change between the four main anime formats: TV Series, Movie, OVA, and Special?
#
# Let's check out TV Series first. For this data set, I have ommitted any entry with an unknown number of episodes. Here are the top five data points as ordered by Rating.

# %%
anime_tv = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'TV' AND episodes != 'Unknown' ORDER BY rating DESC", anime_tv)
anime_data.head()
# Out:
#                                                 name type  rating  user votes
# 0                   Fullmetal Alchemist: Brotherhood   TV    9.26      793665
# 1                                           Gintama°   TV    9.25      114262
# 2                                        Steins;Gate   TV    9.17      673572
# 3                                      Gintama&#039;   TV    9.16      151266
# 4  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...   TV    9.15       93351

# %% [markdown]
# And here are the top five data points as ordered by User Votes.

# %%
anime_tv = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'TV' AND episodes != 'Unknown' ORDER BY members DESC", anime_tv)
anime_data.head()
# Out:
#                                name type  rating  user votes
# 0                        Death Note   TV    8.71     1013917
# 1                Shingeki no Kyojin   TV    8.54      896229
# 2                  Sword Art Online   TV    7.83      893100
# 3  Fullmetal Alchemist: Brotherhood   TV    9.26      793665
# 4                      Angel Beats!   TV    8.39      717796

# %% [markdown]
# This scatter plot displays the Ratings of TV Series against the number of users who voted for them. The y-axis is on a logarithmic scale as to better accentuate the correlation. This y-axis format applies to all following scatter plots as well.

# %%
plt.figure(figsize=(15, 10))

rating = anime_data['rating']
user_votes = anime_data['user votes']

plt.scatter(rating, user_votes)

plt.yscale('log')

plt.title('Ratings vs. Votes: TV Series', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('User Votes', fontsize=14)
# Out:
# Text(0, 0.5, 'User Votes')

# %% [markdown]
# There is a strong positive correlation between TV Series Ratings and their User Votes.
#
# How about Movies, though? Let's check those out. Here are the top five data points as ordered by Rating.

# %%
anime_movies = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'Movie' ORDER BY rating DESC", anime_movies)
anime_data.head()
# Out:
#                                                 name   type  rating  \
# 0            Taka no Tsume 8: Yoshida-kun no X-Files  Movie   10.00
# 1                                   Mogura no Motoro  Movie    9.50
# 2                                     Kimi no Na wa.  Movie    9.37
# 3                                       Kahei no Umi  Movie    9.33
# 4  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...  Movie    9.10
#
#    user votes
# 0          13
# 1          62
# 2      200630
# 3          44
# 4       72534

# %% [markdown]
# And here are the top five data points as ordered by User Votes.

# %%
anime_movies = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'Movie' ORDER BY members DESC", anime_movies)
anime_data.head()
# Out:
#                             name   type  rating  user votes
# 0  Sen to Chihiro no Kamikakushi  Movie    8.93      466254
# 1                  Mononoke Hime  Movie    8.81      339556
# 2            Howl no Ugoku Shiro  Movie    8.74      333186
# 3          Byousoku 5 Centimeter  Movie    8.10      324035
# 4          Toki wo Kakeru Shoujo  Movie    8.44      289206

# %% [markdown]
# This scatter plot displays the Ratings of Movies against the number of users who voted for them.

# %%
plt.figure(figsize=(15, 10))

rating = anime_data['rating']
user_votes = anime_data['user votes']

plt.scatter(rating, user_votes)

plt.yscale('log')

plt.title('Ratings vs. Votes: Movies', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('User Votes', fontsize=14)
# Out:
# Text(0, 0.5, 'User Votes')

# %% [markdown]
# Once again, there is a strong positive correlation between Movie Ratings and their User Votes.
#
# Next, let's take a look at OVAs. Here are the top five data points as ordered by Rating.

# %%
anime_ova = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'OVA' ORDER BY rating DESC", anime_ova)
anime_data.head()
# Out:
#                                                 name type  rating  user votes
# 0                    Yakusoku: Africa Mizu to Midori  OVA    9.25          53
# 1                               Ginga Eiyuu Densetsu  OVA    9.11       80679
# 2          Mienu Me ni Kanjita Kumotoriyama no Asahi  OVA    9.00          47
# 3                          Santa-san wa Dai Isogashi  OVA    9.00          25
# 4  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...  OVA    8.83      129307

# %% [markdown]
# And here are the top five data points as ordered by User Votes.

# %%
anime_ova = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'OVA' ORDER BY members DESC", anime_ova)
anime_data.head()
# Out:
#                                            name type  rating  user votes
# 0                                          FLCL  OVA    8.06      305165
# 1                             Hellsing Ultimate  OVA    8.59      297454
# 2  Highschool of the Dead: Drifters of the Dead  OVA    6.77      140501
# 3                            Mirai Nikki Redial  OVA    7.71      135604
# 4                      Black★Rock Shooter (OVA)  OVA    7.24      130665

# %% [markdown]
# This scatter plot displays the Ratings of OVAs against the number of users who voted for them.

# %%
plt.figure(figsize=(15, 10))

rating = anime_data['rating']
user_votes = anime_data['user votes']

plt.scatter(rating, user_votes)

plt.yscale('log')

plt.title('Ratings vs. Votes: OVAs', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('User Votes', fontsize=14)
# Out:
# Text(0, 0.5, 'User Votes')

# %% [markdown]
# Though there are a few more outliers here than before, there is still a strong positive correlation between OVA Ratings and their User Votes.
#
# Finally, let's process the final category, Special. Here are the top five data points as ordered by Rating.

# %%
anime_special = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'Special' ORDER BY rating DESC", anime_special)
anime_data.head()
# Out:
#                                     name     type  rating  user votes
# 0           Mushishi Special: Hihamukage  Special    8.66       49036
# 1                           Black Clover  Special    8.60        2247
# 2     Mushishi Zoku Shou: Odoro no Michi  Special    8.54       34011
# 3  Steins;Gate: Oukoubakko no Poriomania  Special    8.46      159548
# 4          Hajime no Ippo: Champion Road  Special    8.39       47840

# %% [markdown]
# And here are the top five data points as ordered by User Votes.

# %%
anime_special = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT name, type, rating, members AS 'user votes' FROM anime_data_sql WHERE type = 'Special' ORDER BY members DESC", anime_special)
anime_data.head()
# Out:
#                                                 name     type  rating  \
# 0          Clannad: Mou Hitotsu no Sekai, Tomoyo-hen  Special    8.14
# 1              Steins;Gate: Oukoubakko no Poriomania  Special    8.46
# 2                              Angel Beats! Specials  Special    7.79
# 3  Clannad: After Story - Mou Hitotsu no Sekai, K...  Special    8.02
# 4       Darker than Black: Kuro no Keiyakusha Gaiden  Special    8.09
#
#    user votes
# 0      160423
# 1      159548
# 2      139013
# 3      138364
# 4      136135

# %% [markdown]
# This scatter plot displays the Ratings of Specials against the number of users who voted for them.

# %%
plt.figure(figsize=(15, 10))

rating = anime_data['rating']
user_votes = anime_data['user votes']

plt.scatter(rating, user_votes)

plt.yscale('log')

plt.title('Ratings vs. Votes: Specials', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('User Votes', fontsize=14)
# Out:
# Text(0, 0.5, 'User Votes')

# %% [markdown]
# Yet again, there is a strong positive correlation between Special Ratings and their User Votes.

# %% [markdown]
# **Results: Type vs. User Votes**
#
# For all four type categories, there is a strong positive correlation between the average title Rating and the number of users who voted on them. What I found especially interesting, though, is that the outlier patterns are all the same - in every case, there are some titles that have a small minority of highly dedicated fans, though there are not nearly as many User Votes on them as the more popular and mainstream titles. This affirms that the quality of an anime title is not necessarily determined by the size of its fanbase, especially when the fanbase is highly dedicated to the title.
#
# While we're at it, let's check out which types average the highest in title Rating and User Votes.

# %% [markdown]
# **Comparison: Average Ratings and User Votes**
#
# We'll start with some queries about Ratings.

# %%
anime_tv = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(rating) AS 'Average TV Series Rating' FROM anime_data_sql WHERE type = 'TV' AND episodes != 'Unknown'", anime_tv)
anime_data.head()
# Out:
#    Average TV Series Rating
# 0                  6.929143

# %%
anime_movies = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(rating) AS 'Average Movie Rating' FROM anime_data_sql WHERE type = 'Movie'", anime_movies)
anime_data.head()
# Out:
#    Average Movie Rating
# 0              6.320852

# %%
anime_ova = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(rating) AS 'Average OVA Rating' FROM anime_data_sql WHERE type = 'OVA'", anime_ova)
anime_data.head()
# Out:
#    Average OVA Rating
# 0            6.471376

# %%
anime_special = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(rating) AS 'Average Special Rating' FROM anime_data_sql WHERE type = 'Special'", anime_special)
anime_data.head()
# Out:
#    Average Special Rating
# 0                6.526483

# %% [markdown]
# Excellent! Next, we'll query User Votes again, rounded to the nearest vote.

# %%
anime_tv = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(members) AS 'Average TV Series Votes' FROM anime_data_sql WHERE type = 'TV' AND episodes != 'Unknown'", anime_tv)
round(anime_data).head().astype(int)
# Out:
#    Average TV Series Votes
# 0                    44529

# %%
anime_movies = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(members) AS 'Average Movie Votes' FROM anime_data_sql WHERE type = 'Movie'", anime_movies)
round(anime_data).head().astype(int)
# Out:
#    Average Movie Votes
# 0                10389

# %%
anime_ova = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(members) AS 'Average OVA Votes' FROM anime_data_sql WHERE type = 'OVA'", anime_ova)
round(anime_data).head().astype(int)
# Out:
#    Average OVA Votes
# 0               7657

# %%
anime_special = sqlite3.connect("anime.db")
anime_data = pd.read_sql_query("SELECT AVG(members) AS 'Average Special Votes' FROM anime_data_sql WHERE type = 'Special'", anime_special)
round(anime_data).head().astype(int)
# Out:
#    Average Special Votes
# 0                   7747

# %% [markdown]
# Now that we've found all of our averages, which types came out on top?

# %% [markdown]
# **Results: Averages of Rating & User Votes**
#
# As it turns out, TV Series have both the highest average Rating by a slight margin, and the highest average number of User Votes by far. This is probably because in the world of anime, TV Series have the most international recognition, and therefore, are more likely to be voted on online.

# %% [markdown]
# ## CONCLUSION
#
# Ultimately, my findings were rather surprising. I did not expect any of the categories to display a positive correlation between their Ratings and User Votes. In fact, I expected there to be no correlation whatsoever. However, my initial hypothesis was wrong, based on the given data. I was pleased to find, again, that the positively rated outliers displayed similar trends throughout each category. I was not surprised, though, to find that the TV Series category held the highest average Ratings and number of User Votes.
#
# Thank you for checking out my project - I hope to add more content in the future!
